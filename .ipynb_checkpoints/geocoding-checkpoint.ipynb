# %%
import pandas as pd
import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
import folium
from folium.plugins import FastMarkerCluster

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1862)

# %%
df = pd.read_excel("KHV_2015.xlsx", sheet_name = "KHV_2015", skiprows= 4)

# %%
df.head()
# Out:
#    Land  Kreis  Gemeinde                   Name1                    Name2  \
# 0     1      1         0  Diakonissenkrankenhaus                      NaN
# 1     1      1         0    Malteser Krankenhaus  St. Franziskus Hospital
# 2     1      2         0    Augenklinik Bellevue                      NaN
# 3     1      2         0      Helios Klinik Kiel                      NaN
# 4     1      2         0         Klinik Flechsig                      NaN
#
#   Name3 Name4          Straße/Hausnr    PLZ        Ort Telefonvorwahl/-nummer  \
# 0   NaN   NaN          Knuthstraße 1  24939  Flensburg          0461 8121-100
# 1   NaN   NaN          Waldstraße 17  24939  Flensburg             0461 816-0
# 2   NaN   NaN         Lindenallee 21  24105       Kiel           0431 30108-0
# 3   NaN   NaN  Hamburger Chaussee 77  24113       Kiel          0431 7206-300
# 4   NaN   NaN        Chemnitzstr. 33  24116       Kiel           0431 3397100
#
#   Telefaxvorwahl/-nummer                      E-Mail Adresse  \
# 0          0461 8121-107              servicecenter@diako.de
# 1          0461 816-2012  krankenhaus.flensburg@malteser.org
# 2          0431 30108-40      uthoff@augenklinik-bellevue.de
# 3          0431 7206-315                                 NaN
# 4          0431 66940959             info@klinik-flechsig.de
#
#                       Internetadresse  Traeger  \
# 0                        www.diako.de        4
# 1          www.malteser-franziskus.de        4
# 2         www.augenklinik-bellevue.de        5
# 3  www.helios-kliniken.de/klinik/kiel        5
# 4              www.klinik-flechsig.de        5
#
#                           T_Name1       T_Name2 T_Name3 T_Name4  Art  \
# 0    Ev.-luth. Diakonissenanstalt  zu Flensburg     NaN     NaN    2
# 1  Malteser Norddeutschland gGmbH           NaN     NaN     NaN    2
# 2        Prof. Dr. med. D. Uthoff           NaN     NaN     NaN    2
# 3         Helios Klinik Kiel GmbH           NaN     NaN     NaN    2
# 4   Klinik Flechsig GmbH & Co. KG           NaN     NaN     NaN    2
#
#   Betten_Ins Augen Chirurgie CH_Gefäßchir CH_Thorax CH_Unfall CH_Viszeral  \
# 0        531     1       101           20         -        81           -
# 1        318     -        63            -         -         -           -
# 2         35    35         -            -         -         -           -
# 3         50     -        14            -         -         -           -
# 4         30     -         -            -         -         -           -
#
#   Frauen/Geburt F-Frau F_Geburt HNO Haut_Geschlecht Herzchir Herz_Thorax  \
# 0            66      -        -   -               -        -           -
# 1             -      -        -  20               -        -           -
# 2             -      -        -   -               -        -           -
# 3             -      -        -   1               -        -           -
# 4             -      -        -  30               -        -           -
#
#   Innere I_Angio I_Endo I_Gastro I_Haema I_Kardio I_Nephro I_Pneumo I_Rheuma  \
# 0    107       -      -        -       -        -        -        -        -
# 1    127       -      -        -       -        -        -        -        -
# 2      -       -      -        -       -        -        -        -        -
# 3      -       -      -        -       -        -        -        -        -
# 4      -       -      -        -       -        -        -        -        -
#
#   Geriatrie Kinderchir Kinderhk K_Kardiologie K_Neonatologie Kinderpsychiat  \
# 0         -          -       33             -              -              -
# 1       102          -        -             -              -              -
# 2         -          -        -             -              -              -
# 3         -          -        -             -              -              -
# 4         -          -        -             -              -              -
#
#   Mund_Kiefer Neurochir Neurologie Nuklear Ortho O_Rheuma Plast_Chir Psychiat  \
# 0           -        44         43       -     -        -          8       79
# 1           3         -          -       -     -        -          -        -
# 2           -         -          -       -     -        -          -        -
# 3           1         5          -       -    22        -          -        -
# 4           -         -          -       -     -        -          -        -
#
#   Psychiat_Sucht Psychotherapeut Strahlen Urologie Sonst TN_Innere  \
# 0              -               8        -       38     3         -
# 1              -               -        -        -     3         -
# 2              -               -        -        -     -         -
# 3              -               -        -        7     -         -
# 4              -               -        -        -     -         -
#
#   TN_I_Geriatrie TN_Kinderpsychiat TN_Psychiat TN_Psychotherapeut TN_Sonst  \
# 0              -                25          48                 15        -
# 1             37                 -           -                  -        -
# 2              -                 -           -                  -        -
# 3              -                 -           -                  -        -
# 4              -                 -           -                  -        -
#
#   TN_SUM  Änd_Art Änd_Detail
# 0     88      NaN        NaN
# 1     37      NaN        NaN
# 2      -      NaN        NaN
# 3      -      NaN        NaN
# 4      -      NaN        NaN

# %%
df = df[['Land', 'Kreis', 'Gemeinde', 'Name1', 'Traeger', 'Straße/Hausnr', 'PLZ', 'Ort']]

# %%
df.sample(30)
# Out:
#       Land  Kreis  Gemeinde                              Name1  Traeger  \
# 299      3    459        29             Niels-Stensen-Kliniken        4
# 1328     9    362         0                    Bezirksklinikum        2
# 444      5    315         0          St. Elisabeth-Krankenhaus        4
# 50       1     56         8                 Fachklinik Bokholt        4
# 574      5    770         4         Krankenhaus Bad Oeynhausen        2
# 961      8    136        19          St. Anna-Virngrund-Klinik        1
# 180      3    251         7                      Klinik Bassum        4
# 1711    14    522       360    Landkreis Mittweida Krankenhaus        3
# 525      5    558        20            Klinik am Schlossgarten        4
# 1693    13     76        14                        Krankenhaus        5
# 1569    11      4         4       Sankt Gertrauden-Krankenhaus        4
# 943      8    121         0        Privatklinik Dr. Marquetand        5
# 958      8    128       115                   Kreiskrankenhaus        4
# 656      5    974        28           Dreifaltigkeits-Hospital        4
# 1138     8    435        57               Klinik Tettnang GmbH        5
# 1142     8    436         9           Oberschwaben Klinik GmbH        4
# 1439     9    672       135  Thoraxzentrum Bezirk Unterfranken        1
# 1029     8    236        46                 Klinik Öschelbronn        4
# 1418     9    661         0                       Frauenklinik        5
# 1006     8    226        84            GRN-Klinik Schwetzingen        3
# 197      3    254        21           St. Bernward Krankenhaus        4
# 201      3    256        32   HELIOS Kliniken Mittelweser GmbH        5
# 1346     9    376       119                   Asklepios Klinik        5
# 5        1      2         0                   Lubinus-Clinicum        4
# 320      4     12         0          Tagesklinik Virchowstraße        4
# 416      5    170        48                    Ev. Krankenhaus        4
# 632      5    958        40                    Fachkrankenhaus        4
# 1214     9    172       114    Klinik für Schlafstörungen GmbH        5
# 1096     8    336        50  St. Elisabethen-Krankenhaus gGmbH        4
# 1280     9    188       124                       Privatklinik        5
#
#                   Straße/Hausnr    PLZ                  Ort
# 299            Bremer Straße 31  49179         Ostercappeln
# 1328        Universitätsstr. 84  93053           Regensburg
# 444             Werthmannstr. 1  50935                 Köln
# 50            Hanredder 30 - 32  25335    Bokholt-Hanredder
# 574              Wielandstr. 28  32545       Bad Oeynhausen
# 961       Dalkinger Str. 8 - 12  73479            Ellwangen
# 180     Marie-Hackfeld-Straße 6  27211               Bassum
# 1711       Hainichener Str. 4-6   9648            Mittweida
# 525         Am Schlossgarten 10  48429               Dülmen
# 1693        Vor dem Mühlentor 3  19258      Boizenburg/Elbe
# 1569        Paretzer Strasse 12  10713               Berlin
# 943                    Allee 40  74072            Heilbronn
# 958   Albert-Schweitzer-Str. 37  97941   Tauberbischofsheim
# 656              Klosterstr. 31  59555            Lippstadt
# 1138         Emil-Münch-Str. 16  88069             Tettnang
# 1142        Robert-Koch-Str. 38  88339          Bad Waldsee
# 1439              Michelsberg 1  97702          Münnerstadt
# 1029              Am Eichhof 30  75223  Niefern-Öschelbronn
# 1418           Ziegelbergstr. 5  63739        Aschaffenburg
# 1006       Bodelschwinghstr. 10  68723         Schwetzingen
# 197              Treibestraße 9  31134           Hildesheim
# 201           Holzhäuser Weg 28  31592            Stolzenau
# 1346      Dr.-Sauerbruch-Str. 1  93133       Burglengenfeld
# 5             Steenbeker Weg 25  24106                 Kiel
# 320             Virchowstraße 6  27574          Bremerhaven
# 416    Schermbecker Landstr. 88  46485                Wesel
# 632                  Annostr. 1  57392        Schmallenberg
# 1214              Rinckstr. 7-9  83435      Bad Reichenhall
# 1096            Feldbergstr. 15  79539              Lörrach
# 1280                 Seestr. 43  82211           Herrsching

# %% [markdown]
# ## Limit dataset to NRW

# %%
df = df.loc[lambda df: df['Land'] == 5]

# %%
df.sample(30)
# Out:
#      Land  Kreis  Gemeinde                          Name1  Traeger  \
# 408     5    166        32        Allgemeines Krankenhaus        4
# 453     5    334         2             Franziskushospital        4
# 594     5    913         0              Klinikum Dortmund        3
# 466     5    358        36          St. Josef-Krankenhaus        4
# 658     5    974        28           LWL-Klinik Lippstadt        1
# 336     5    112         0       Ev. Bethesda Krankenhaus        4
# 627     5    958        24            LWL-Klinik Marsberg        1
# 494     5    382         8                   Rhein-Klinik        4
# 553     5    711         0         Fachkrankenhaus Bethel        4
# 493     5    382         8              Kath. Krankenhaus        4
# 642     5    962        32                 Berglandklinik        5
# 540     5    566        28            Klinikum Ibbenbüren        4
# 406     5    166        16             Städt. Krankenhaus        3
# 515     5    515         0        St. Franziskus-Hospital        4
# 580     5    774         8             Karl-Hansen-Klinik        3
# 353     5    113         0            LVR-Klinikum Essen/        1
# 556     5    711         0              Klinik Dr. Hartog        5
# 381     5    154         8          St. Willibrord-Spital        4
# 385     5    154        32    Kath. Karl-Leisner-Klinikum        4
# 471     5    362        24        St. Katharinen-Hospital        4
# 391     5    158        20       St. Martinus-Krankenhaus        4
# 663     5    974        52             Mariannen-Hospital        4
# 417     5    170        48                Marien-Hospital        4
# 626     5    958        12  Städt. Krankenhaus Maria-Hilf        3
# 641     5    962        24        Marienhospital Letmathe        3
# 455     5    334         2                 Marienhospital        4
# 527     5    562         4                Ev. Krankenhaus        4
# 413     5    170        20          St. Bernhard-Hospital        4
# 357     5    114         0               Klinik Königshof        4
# 628     5    958        24            LWL-Klinik Marsberg        1
#
#                         Straße/Hausnr    PLZ              Ort
# 408                  Hoserkirchweg 63  41747          Viersen
# 453                   Morillenhang 27  52074           Aachen
# 594                   Beurhausstr. 40  44137         Dortmund
# 466                 Rurdorfer Str. 49  52441          Linnich
# 658                      Im Hofholz 6  59556        Lippstadt
# 336                      Heerstr. 219  47053         Duisburg
# 627                Bredelarer Str. 33  34431         Marsberg
# 494                      Luisenstr. 3  53604       Bad Honnef
# 553                         Maraweg 9  33617        Bielefeld
# 493                   Schülgenstr. 15  53604       Bad Honnef
# 642                   Am Hundebrink 6  58511      Lüdenscheid
# 540                     Große Str. 41  49477       Ibbenbüren
# 406           Sassenfelder Kirchweg 1  41334         Nettetal
# 515               Hohenzollernring 72  48145          Münster
# 580                   Antoniusstr. 19  33175  Bad Lippspringe
# 353                   Hufelandstr. 55  45147            Essen
# 556                    Kisker Str. 15  33615        Bielefeld
# 381                  Willibrordstr. 9  46446         Emmerich
# 385                   Basilikastr. 55  47623         Kevelaer
# 471                  Kapellenstr. 1-5  50226          Frechen
# 391                    Klosterstr. 32  40764       Langenfeld
# 663                    Unnaer Str. 15  59457             Werl
# 417           Pastor-Janßen-Str. 8-38  46483            Wesel
# 626                    Am Schönschede  59929           Brilon
# 641                  Hagener Str. 121  58642         Iserlohn
# 455                           Zeise 4  52066           Aachen
# 527                  Grutholzallee 21  44577   Castrop-Rauxel
# 413  Bürgermeister-Schmelzing-Str. 90  47475    Kamp-Lintfort
# 357      Am Dreifaltigkeitskloster 16  47807          Krefeld
# 628                          Weist 45  34431         Marsberg

# %% [markdown]
# ## Limit dataset to one city to test API

# %%
df = df.loc[lambda df: df['Ort'] == "Essen"]

# %%
df.sample(10)
# Out:
#      Land  Kreis  Gemeinde                         Name1  Traeger  \
# 354     5    113         0                Ruhrlandklinik        3
# 345     5    113         0         Elisabeth-Krankenhaus        4
# 348     5    113         0          Kath. Klinikum Essen        4
# 350     5    113         0          Kliniken Essen-Mitte        4
# 344     5    113         0     Alfried-Krupp-Krankenhaus        4
# 349     5    113         0          Kath. Klinikum Essen        4
# 351     5    113         0            Kliniken Essen-Süd        4
# 353     5    113         0           LVR-Klinikum Essen/        1
# 352     5    113         0            Kliniken Essen-Süd        4
# 347     5    113         0  Kath. Kliniken Ruhrhalbinsel        4
#
#              Straße/Hausnr    PLZ    Ort
# 354       Tüschener Weg 40  45239  Essen
# 345       Klara-Kopp-Weg 1  45138  Essen
# 348        Hospitalstr. 24  45329  Essen
# 350         Henricistr. 92  45136  Essen
# 344  Alfried-Krupp-Str. 21  45117  Essen
# 349        Hülsmannstr. 17  45355  Essen
# 351       Pattbergstr. 1-3  45239  Essen
# 353        Hufelandstr. 55  45147  Essen
# 352         Propsteistr. 2  45239  Essen
# 347      Heidbergweg 22-24  45257  Essen

# %% [markdown]
# ## Concatenate address

# %%
df = df.applymap(str)

# %%
df['address'] = df['Straße/Hausnr'].astype(str) + ', ' + \
                df['PLZ'] + ', ' + \
                df['Ort'] + ', ' + 'Germany'

# %%
df
# Out:
#     Land Kreis Gemeinde                             Name1 Traeger  \
# 343    5   113        0  Alfried Krupp Krankenhaus Steele       4
# 344    5   113        0         Alfried-Krupp-Krankenhaus       4
# 345    5   113        0             Elisabeth-Krankenhaus       4
# 346    5   113        0              Facharztklinik Essen       5
# 347    5   113        0      Kath. Kliniken Ruhrhalbinsel       4
# 348    5   113        0              Kath. Klinikum Essen       4
# 349    5   113        0              Kath. Klinikum Essen       4
# 350    5   113        0              Kliniken Essen-Mitte       4
# 351    5   113        0                Kliniken Essen-Süd       4
# 352    5   113        0                Kliniken Essen-Süd       4
# 353    5   113        0               LVR-Klinikum Essen/       1
# 354    5   113        0                    Ruhrlandklinik       3
# 355    5   113        0        Universitätsklinikum Essen       2
#
#              Straße/Hausnr    PLZ    Ort  \
# 343            Hellweg 100  45276  Essen
# 344  Alfried-Krupp-Str. 21  45117  Essen
# 345       Klara-Kopp-Weg 1  45138  Essen
# 346      Girardetstr. 2-38  45131  Essen
# 347      Heidbergweg 22-24  45257  Essen
# 348        Hospitalstr. 24  45329  Essen
# 349        Hülsmannstr. 17  45355  Essen
# 350         Henricistr. 92  45136  Essen
# 351       Pattbergstr. 1-3  45239  Essen
# 352         Propsteistr. 2  45239  Essen
# 353        Hufelandstr. 55  45147  Essen
# 354       Tüschener Weg 40  45239  Essen
# 355        Hufelandstr. 55  45147  Essen
#
#                                           address
# 343            Hellweg 100, 45276, Essen, Germany
# 344  Alfried-Krupp-Str. 21, 45117, Essen, Germany
# 345       Klara-Kopp-Weg 1, 45138, Essen, Germany
# 346      Girardetstr. 2-38, 45131, Essen, Germany
# 347      Heidbergweg 22-24, 45257, Essen, Germany
# 348        Hospitalstr. 24, 45329, Essen, Germany
# 349        Hülsmannstr. 17, 45355, Essen, Germany
# 350         Henricistr. 92, 45136, Essen, Germany
# 351       Pattbergstr. 1-3, 45239, Essen, Germany
# 352         Propsteistr. 2, 45239, Essen, Germany
# 353        Hufelandstr. 55, 45147, Essen, Germany
# 354       Tüschener Weg 40, 45239, Essen, Germany
# 355        Hufelandstr. 55, 45147, Essen, Germany

# %% [markdown]
# ## Get location and point

# %%
locator = Nominatim(user_agent="myFancyGeocoder")
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
df['location'] = df['address'].apply(geocode)
df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
df.head()
# Out:
#     Land Kreis Gemeinde                             Name1 Traeger  \
# 343    5   113        0  Alfried Krupp Krankenhaus Steele       4
# 344    5   113        0         Alfried-Krupp-Krankenhaus       4
# 345    5   113        0             Elisabeth-Krankenhaus       4
# 346    5   113        0              Facharztklinik Essen       5
# 347    5   113        0      Kath. Kliniken Ruhrhalbinsel       4
#
#              Straße/Hausnr    PLZ    Ort  \
# 343            Hellweg 100  45276  Essen
# 344  Alfried-Krupp-Str. 21  45117  Essen
# 345       Klara-Kopp-Weg 1  45138  Essen
# 346      Girardetstr. 2-38  45131  Essen
# 347      Heidbergweg 22-24  45257  Essen
#
#                                           address  \
# 343            Hellweg 100, 45276, Essen, Germany
# 344  Alfried-Krupp-Str. 21, 45117, Essen, Germany
# 345       Klara-Kopp-Weg 1, 45138, Essen, Germany
# 346      Girardetstr. 2-38, 45131, Essen, Germany
# 347      Heidbergweg 22-24, 45257, Essen, Germany
#
#                                               location  \
# 343  (Alfried Krupp Krankenhaus Steele, 100, Hellwe...
# 344  (Alfried-Krupp-Krankenhaus, 21, Alfried-Krupp-...
# 345  (Klara-Kopp-Weg, Huttrop, Stadtbezirk I, Essen...
# 346  (2-38, Girardetstraße, Witteringsfeld, Rüttens...
# 347  (St.Josef Krankenhaus, 22-24, Heidbergweg, Dil...
#
#                                       point
# 343  (51.44994975, 7.0919823731518346, 0.0)
# 344   (51.42623705, 7.007627003459746, 0.0)
# 345            (51.4456041, 7.0331828, 0.0)
# 346            (51.4308573, 7.0055116, 0.0)
# 347    (51.3916617, 7.085786276566124, 0.0)

# %% [markdown]
# ## Split point into lattitude, longitude and attitude

# %%
df[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df['point'].tolist(), index=df.index)

# %%
df.head()
# Out:
#     Land Kreis Gemeinde                             Name1 Traeger  \
# 343    5   113        0  Alfried Krupp Krankenhaus Steele       4
# 344    5   113        0         Alfried-Krupp-Krankenhaus       4
# 345    5   113        0             Elisabeth-Krankenhaus       4
# 346    5   113        0              Facharztklinik Essen       5
# 347    5   113        0      Kath. Kliniken Ruhrhalbinsel       4
#
#              Straße/Hausnr    PLZ    Ort  \
# 343            Hellweg 100  45276  Essen
# 344  Alfried-Krupp-Str. 21  45117  Essen
# 345       Klara-Kopp-Weg 1  45138  Essen
# 346      Girardetstr. 2-38  45131  Essen
# 347      Heidbergweg 22-24  45257  Essen
#
#                                           address  \
# 343            Hellweg 100, 45276, Essen, Germany
# 344  Alfried-Krupp-Str. 21, 45117, Essen, Germany
# 345       Klara-Kopp-Weg 1, 45138, Essen, Germany
# 346      Girardetstr. 2-38, 45131, Essen, Germany
# 347      Heidbergweg 22-24, 45257, Essen, Germany
#
#                                               location  \
# 343  (Alfried Krupp Krankenhaus Steele, 100, Hellwe...
# 344  (Alfried-Krupp-Krankenhaus, 21, Alfried-Krupp-...
# 345  (Klara-Kopp-Weg, Huttrop, Stadtbezirk I, Essen...
# 346  (2-38, Girardetstraße, Witteringsfeld, Rüttens...
# 347  (St.Josef Krankenhaus, 22-24, Heidbergweg, Dil...
#
#                                       point   latitude  longitude  altitude
# 343  (51.44994975, 7.0919823731518346, 0.0)  51.449950   7.091982       0.0
# 344   (51.42623705, 7.007627003459746, 0.0)  51.426237   7.007627       0.0
# 345            (51.4456041, 7.0331828, 0.0)  51.445604   7.033183       0.0
# 346            (51.4308573, 7.0055116, 0.0)  51.430857   7.005512       0.0
# 347    (51.3916617, 7.085786276566124, 0.0)  51.391662   7.085786       0.0

# %% [markdown]
# ## Clean up columns

# %%
df.columns
# Out:
# Index(['Land', 'Kreis', 'Gemeinde', 'Name1', 'Traeger', 'Straße/Hausnr', 'PLZ',
#        'Ort', 'address', 'location', 'point', 'latitude', 'longitude',
#        'altitude'],
#       dtype='object')

# %%
df = df.drop(['Land', 'Kreis', 'Gemeinde', 'Straße/Hausnr','PLZ', 'Ort', 'address', 'location', 'point'], axis=1)

# %%
df.head()
# Out:
#                                 Name1 Traeger   latitude  longitude  altitude
# 343  Alfried Krupp Krankenhaus Steele       4  51.449950   7.091982       0.0
# 344         Alfried-Krupp-Krankenhaus       4  51.426237   7.007627       0.0
# 345             Elisabeth-Krankenhaus       4  51.445604   7.033183       0.0
# 346              Facharztklinik Essen       5  51.430857   7.005512       0.0
# 347      Kath. Kliniken Ruhrhalbinsel       4  51.391662   7.085786       0.0

# %%
df.latitude.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Make map

# %%
map1 = folium.Map(
    location=[51.452441, 7.019965],
    tiles='cartodbpositron',
    zoom_start=10,
)

# %% [markdown]
# ## Add markers

# %%
df.apply(lambda row:folium.CircleMarker(location=[row["latitude"], row["longitude"]]).add_to(map1), axis=1)
# Out:
# 343    <folium.vector_layers.CircleMarker object at 0...
# 344    <folium.vector_layers.CircleMarker object at 0...
# 345    <folium.vector_layers.CircleMarker object at 0...
# 346    <folium.vector_layers.CircleMarker object at 0...
# 347    <folium.vector_layers.CircleMarker object at 0...
# 348    <folium.vector_layers.CircleMarker object at 0...
# 349    <folium.vector_layers.CircleMarker object at 0...
# 350    <folium.vector_layers.CircleMarker object at 0...
# 351    <folium.vector_layers.CircleMarker object at 0...
# 352    <folium.vector_layers.CircleMarker object at 0...
# 353    <folium.vector_layers.CircleMarker object at 0...
# 354    <folium.vector_layers.CircleMarker object at 0...
# 355    <folium.vector_layers.CircleMarker object at 0...
# dtype: object

# %%
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Save map as html

# %%
map1.save("map1.html")

# %% [markdown]
# ## Credits and Thanks

# %% [markdown]
# [Abdishakur](https://towardsdatascience.com/@shakasom) and his article [Geocode with Python](https://towardsdatascience.com/geocode-with-python-161ec1e62b89)
