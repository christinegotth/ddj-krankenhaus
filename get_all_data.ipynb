# %%
import pandas as pd

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1862)

# %% [markdown]
# ## 1992

# %%
df_1992 = pd.read_excel('KHV_1992.xls', dtype='object')

# %%
df_1992.sample()
# Out:
#      LAND REGBEZ KREIS GEMEINDE                 NAME1 NAME2 NAME3 NAME4  \
# 1695   09      3    73      112  Stiftungskrankenhaus   NaN   NaN   NaN
#
#                   STRASSE    PLZ       ORT       TELEFON TRAEGER  \
# 1695  Krankenhausstraáe 3  92334  Berching  (08462)-2050       1
#
#               NAMET1 NAMET2 NAMET3 NAMET4 ART BETTEN_P BETTEN_I AUGEN_P  \
# 1695  Stadt Berching    NaN    NaN    NaN   2       47       47       0
#
#      AUGEN_I CHIR_P CHIR_I C_GEF_P C_GEF_I C_KIN_P C_KIN_I C_PLA_P C_PLA_I  \
# 1695       0      0      0       0       0       0       0       0       0
#
#      C_THOR_P C_THOR_I C_UNF_P C_UNF_I FRAUEN_P FRAUEN_I F_FRAU_P F_FRAU_I  \
# 1695        0        0       0       0        0        0        0        0
#
#      F_GEBURT F_GEBUR0 HNO_P HNO_I HUG_P HUG_I INNERE_P INNERE_I I_ENDO_P  \
# 1695        0        0     0     0     0     0        0        0        0
#
#      I_ENDO_I I_GAST_P I_GAST_I I_HAEM_P I_HAEM_I I_KARD_P I_KARD_I I_LUB_P  \
# 1695        0        0        0        0        0        0        0       0
#
#      I_LUB_I I_NEPH_P I_NEPH_I I_RHEUM_ I_RHEUM1 I_GER_P I_GER_I KINDER_P  \
# 1695       0        0        0        0        0       0       0        0
#
#      KINDER_I KJPSYCH_ KJPSYCH2 MKG_P MKG_I NEURCH_P NEURCH_I NEUROL_P  \
# 1695        0        0        0     0     0        0        0        0
#
#      NEUROL_I NUKLEAR_ NUKLEAR3 ORTH_P ORTH_I O_RHEU_P O_RHEU_I PSYCH_P  \
# 1695        0        0        0      0      0        0        0       0
#
#      PSYCH_I P_SUCHT_ P_SUCHT4 PSYSOM_P PSYSOM_I STRAHL_P STRAHL_I UROL_P  \
# 1695       0        0        0        0        0        0        0      0
#
#      UROL_I SONST_P SONST_I TN_GER TN_KJPSY TN_PSYCH TN_PSYSO TN_SONST TN_SUM
# 1695      0      47      47      0        0        0        0        0      0

# %%
df_1992.columns
# Out:
# Index(['LAND', 'REGBEZ', 'KREIS', 'GEMEINDE', 'NAME1', 'NAME2', 'NAME3',
#        'NAME4', 'STRASSE', 'PLZ', 'ORT', 'TELEFON', 'TRAEGER', 'NAMET1',
#        'NAMET2', 'NAMET3', 'NAMET4', 'ART', 'BETTEN_P', 'BETTEN_I', 'AUGEN_P',
#        'AUGEN_I', 'CHIR_P', 'CHIR_I', 'C_GEF_P', 'C_GEF_I', 'C_KIN_P',
#        'C_KIN_I', 'C_PLA_P', 'C_PLA_I', 'C_THOR_P', 'C_THOR_I', 'C_UNF_P',
#        'C_UNF_I', 'FRAUEN_P', 'FRAUEN_I', 'F_FRAU_P', 'F_FRAU_I', 'F_GEBURT',
#        'F_GEBUR0', 'HNO_P', 'HNO_I', 'HUG_P', 'HUG_I', 'INNERE_P', 'INNERE_I',
#        'I_ENDO_P', 'I_ENDO_I', 'I_GAST_P', 'I_GAST_I', 'I_HAEM_P', 'I_HAEM_I',
#        'I_KARD_P', 'I_KARD_I', 'I_LUB_P', 'I_LUB_I', 'I_NEPH_P', 'I_NEPH_I',
#        'I_RHEUM_', 'I_RHEUM1', 'I_GER_P', 'I_GER_I', 'KINDER_P', 'KINDER_I',
#        'KJPSYCH_', 'KJPSYCH2', 'MKG_P', 'MKG_I', 'NEURCH_P', 'NEURCH_I',
#        'NEUROL_P', 'NEUROL_I', 'NUKLEAR_', 'NUKLEAR3', 'ORTH_P', 'ORTH_I',
#        'O_RHEU_P', 'O_RHEU_I', 'PSYCH_P', 'PSYCH_I', 'P_SUCHT_', 'P_SUCHT4',
#        'PSYSOM_P', 'PSYSOM_I', 'STRAHL_P', 'STRAHL_I', 'UROL_P', 'UROL_I',
#        'SONST_P', 'SONST_I', 'TN_GER', 'TN_KJPSY', 'TN_PSYCH', 'TN_PSYSO',
#        'TN_SONST', 'TN_SUM'],
#       dtype='object')

# %%
# TODO: Prüfen: Steht BETTEN_I für Betten insgesamt?
df_1992 = df_1992.rename(columns={'LAND': 'Land', 'KREIS': 'Kreis', 'GEMEINDE': 'Gemeinde', 'NAME1': 'Name1', 'ORT': 'Ort', 'TRAEGER': 'Traeger', 'NAMET1': 'T_Name1', 'ART':'Art', 'BETTEN_I': 'Betten_Ins'})

# %%
df_1992 = df_1992[['Land', 'Kreis', 'Gemeinde', 'Name1', 'Ort', 'Traeger', 'T_Name1', 'Art', 'Betten_Ins']]

# %% [markdown]
# ## 1995

# %%
df_1995 = pd.read_excel('KHV_1995.XLS', 'KH', dtype='object')

# %%
# TODO: Prüfen: Steht BETTEN_I für Betten insgesamt?
df_1995 = df_1995.rename(columns={'LAND': 'Land', 'KREIS': 'Kreis', 'GEMEINDE': 'Gemeinde', 'NAME1': 'Name1', 'ORT': 'Ort', 'TRAEGER': 'Traeger', 'NAMET1': 'T_Name1', 'ART':'Art', 'BETTEN_I': 'Betten_Ins'})

# %%
df_1995 = df_1995[['Land', 'Kreis', 'Gemeinde', 'Name1', 'Ort', 'Traeger', 'T_Name1', 'Art', 'Betten_Ins']]

# %%
df_1995.dtypes
# Out:
# Land          object
# Kreis         object
# Gemeinde      object
# Name1         object
# Ort           object
# Traeger       object
# T_Name1       object
# Art           object
# Betten_Ins    object
# dtype: object

# %%
df_2003 = df_2003[['Land', 'Kreis', 'Gemeinde', 'Name1', 'Ort', 'Traeger', 'T_Name1', 'Art', 'Betten_Ins']]

# %% [markdown]
# ## 2003 - 2005

# %%
filenames = [
 'KHV_2003.xls',
 'KHV_2004.xls',
 'KHV_2005.xls',]

# %%
df_from_each_file = (pd.read_excel(file, 'KHV', dtype='object') for f in filenames)
df_2003_2005 = pd.concat(df_from_each_file, ignore_index=True)

# %%
df_2003_2005 = df_2003_2005[['Land', 'Kreis', 'Gemeinde', 'Name1', 'Ort', 'Traeger', 'T_Name1', 'Art', 'Betten_Ins']]

# %% [markdown]
# ## 2006 - 2015

# %%
filenames =  [
 'KHV_2006.xls',
 'KHV_2007.xls',
 'KHV_2008.xls',
 'KHV_2009.xls',
 'KHV_2010.xls',
 'KHV_2011.xls',
 'KHV_2012.xlsx',
 'KHV_2013.xlsx',
 'KHV_2014.xlsx',
 'KHV_2015.xlsx']

# %%
df_from_each_file = (pd.read_excel(file, 'KHV', dtype='object') for f in filenames)
df_2006_20025 = pd.concat(df_from_each_file, ignore_index=True)

# %%
df_2006_2015 = df_2003_2005[['Land', 'Kreis', 'Gemeinde', 'Name1', 'Ort', 'Traeger', 'T_Name1', 'Art', 'Betten_Ins']]

# %% [markdown]
# ## Add more columns

# %%
def label_art(row):
    if row == 1 :
        return "Uniklinik"
    if row == 2 :
        return "Plankrankenhaus"
    if row == 3 :
        return "mit Versorgungsvertrag"
    if row == 4 :
        return "ohne Versorgungsvertrag"
    if row == 5 :
        return "Bundeswehrkrankenhaus"

# %%
def clean_betreiber(x):
    if 'HELIOS' in x:
        return 'HELIOS'
    #TODO Check for other betreiber
    else:
        return x

# %%
def add_more_columns(df):
    df.Traeger = df.Traeger.astype('int')
    df["private_traeger"]= df.Traeger.apply(lambda x: "oeffentlich" if x <= 4 else "privat")
    df["art_text"]= df.Art.apply(lambda x: label_art(x))
    df["betreiber"] = df.T_Name1.str.strip().str.upper()
    df.betreiber = df.betreiber.astype('str')
    df.betreiber = df.betreiber.apply(clean_betreiber)
    df.Betten_Ins = df.Betten_Ins.astype('int', errors='ignore')
    return df

# %%
df_1992 = add_more_columns(df_1992)

# %%
df_1995 = add_more_columns(df_1995)

# %%
df_2003_2005 = add_more_columns(df_2003_2005)
#Todo Convert floats to int?
# Out:
# /home/p3nny/2_wdr-data/ddj-krankenhaus/myvenv/lib/python3.6/site-packages/pandas/core/generic.py:5159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /home/p3nny/2_wdr-data/ddj-krankenhaus/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/p3nny/2_wdr-data/ddj-krankenhaus/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/p3nny/2_wdr-data/ddj-krankenhaus/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_2003_2005.sample()
# Out:
#      Land Kreis Gemeinde                      Name1                    Ort  \
# 3198   07   314      000  Berufsgenossenschaftliche  Ludwigshafen am Rhein
#
#       Traeger                     T_Name1 Art Betten_Ins private_traeger  \
# 3198        3  Verein für Berufsgenossen-   3        355     oeffentlich
#
#      art_text                   betreiber
# 3198     None  VEREIN FÜR BERUFSGENOSSEN-

# %%
df_2006_2015 = add_more_columns(df_2006_2015)
# Out:
# /home/p3nny/2_wdr-data/ddj-krankenhaus/myvenv/lib/python3.6/site-packages/pandas/core/generic.py:5159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /home/p3nny/2_wdr-data/ddj-krankenhaus/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/p3nny/2_wdr-data/ddj-krankenhaus/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df_2006_2015.sample()
# Out:
#      Land Kreis Gemeinde                           Name1         Ort  Traeger  \
# 3355   08   221      000  St.Vincentius-Krankenhaus e.V.  Heidelberg        4
#
#                               T_Name1 Art Betten_Ins private_traeger art_text  \
# 3355  St. Vincentius-Krankenhaus e.V.   2         84     oeffentlich     None
#
#                             betreiber
# 3355  ST. VINCENTIUS-KRANKENHAUS E.V.

# %% [markdown]
# ## Bring them all together

# %%
dfs = [df_1992, df_1995, df_2003_2005, df_2006_2015]

# %%
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#       Land Kreis Gemeinde                             Name1        Ort  \
# 0       01    01      000      Privatklinik Dr. Dunckelmann  Flensburg
# 1       01    01      000           Evangelisch-lutherische  Flensburg
# 2       01    01      000        Psychiatrische Tagesklinik  Flensburg
# 3       01    01      000           St. Franziskus-Hospital  Flensburg
# 4       01    01      000       St„dtische Krankenanstalten  Flensburg
# ...    ...   ...      ...                               ...        ...
# 17548   16   076      022             Klinik ProLeben Greiz      Greiz
# 17549   16   076      061        Kreiskrankenhaus Ronneburg  Ronneburg
# 17550   16   077      001  Kreiskrankenhaus Altenburg gGmbH  Altenburg
# 17551   16   077      001       Evangelische Lukas-Stiftung  Altenburg
# 17552   16   077      043        Krankenhaus Schmölln gGmbH   Schmölln
#
#        Traeger                      T_Name1 Art Betten_Ins private_traeger  \
# 0            3         Dr. med. Dunckelmann   2         20     oeffentlich
# 1            2      Evangelisch-lutherische   2        395     oeffentlich
# 2            2      Evangelisch-lutherische   2          0     oeffentlich
# 3            2           Genossenschaft der   2        337     oeffentlich
# 4            1              Stadt Flensburg   2        140     oeffentlich
# ...        ...                          ...  ..        ...             ...
# 17548        5                     ProLeben   4         12          privat
# 17549        3              Landkreis Greiz   2        100     oeffentlich
# 17550        3             Kreiskrankenhaus   2        496     oeffentlich
# 17551        4  Evangelische Lukas-Stiftung   2         60     oeffentlich
# 17552        3   Krankenhaus Schmölln gGmbH   2        113     oeffentlich
#
#               art_text                    betreiber
# 0      Plankrankenhaus         DR. MED. DUNCKELMANN
# 1      Plankrankenhaus      EVANGELISCH-LUTHERISCHE
# 2      Plankrankenhaus      EVANGELISCH-LUTHERISCHE
# 3      Plankrankenhaus           GENOSSENSCHAFT DER
# 4      Plankrankenhaus              STADT FLENSBURG
# ...                ...                          ...
# 17548             None                     PROLEBEN
# 17549             None              LANDKREIS GREIZ
# 17550             None             KREISKRANKENHAUS
# 17551             None  EVANGELISCHE LUKAS-STIFTUNG
# 17552             None   KRANKENHAUS SCHMÖLLN GGMBH
#
# [17553 rows x 12 columns]
